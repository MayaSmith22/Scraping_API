# %%
import requests
import pandas as pd

# %%
cookies = {
    'ec': 'eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKE1hY2ludG9zaDsgSW50ZWwgTWFjIE9TIFggMTBfMTRfNikgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk5LjAuNDg0NC44MyBTYWZhcmkvNTM3LjM2In0=',
    'client_guid_timestamp': '4693059d-f30a-4ccb-81eb-f719547db0df.1648326652603',
    '_fbp': 'fb.1.1648326652869.1949719072',
    'scavenger-a493': '...',
    '_sp_ses.8ca5': '*',
    '__gads': 'ID=33b658d4ee09aa1c:T=1648326653:S=ALNI_MZr1AcRTKC-x8KFudBGqRrCJfuoCw',
    '_ga': 'GA1.2.1724804240.1648326652',
    '_gid': 'GA1.2.1034910914.1648326654',
    'cto_bundle': '',
    'g_state': '{"i_p":1648333861734,"i_l":1}',
    '_ga_152345333': 'GS1.1.1648326651.1.0.1648326667.0',
    'AMP_TOKEN': '%24NOT_FOUND',
    'sp-nuid': '7de445b2-c573-4c72-b479-120ddb0cc6a0',
    '_gcl_au': '1.1.1086527863.1648326669',
    '_gat': '1',
    '_sp_id.8ca5': 'ef660d57-4be6-4c60-83dc-61153f076a9f.1648326653.1.1648326808.1648326653.f4b08557-b5f0-4942-b6c8-25f3f3eaf2f6',
}

headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="99", "Google Chrome";v="99"',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': '9412771d-9651-4b27-a44f-524e6fa7a79b',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.83 Safari/537.36',
    'sec-ch-ua-platform': '"macOS"',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    # Requests sorts cookies= alphabetically
    # 'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKE1hY2ludG9zaDsgSW50ZWwgTWFjIE9TIFggMTBfMTRfNikgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk5LjAuNDg0NC44MyBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=4693059d-f30a-4ccb-81eb-f719547db0df.1648326652603; _fbp=fb.1.1648326652869.1949719072; scavenger-a493=...; _sp_ses.8ca5=*; __gads=ID=33b658d4ee09aa1c:T=1648326653:S=ALNI_MZr1AcRTKC-x8KFudBGqRrCJfuoCw; _ga=GA1.2.1724804240.1648326652; _gid=GA1.2.1034910914.1648326654; cto_bundle=; g_state={"i_p":1648333861734,"i_l":1}; _ga_152345333=GS1.1.1648326651.1.0.1648326667.0; AMP_TOKEN=%24NOT_FOUND; sp-nuid=7de445b2-c573-4c72-b479-120ddb0cc6a0; _gcl_au=1.1.1086527863.1648326669; _gat=1; _sp_id.8ca5=ef660d57-4be6-4c60-83dc-61153f076a9f.1648326653.1.1648326808.1648326653.f4b08557-b5f0-4942-b6c8-25f3f3eaf2f6',
}

response = requests.get('https://www.autolist.com/api/cwv/seo/listings?make=Tesla&location=Greensboro,%20NC&latitude=36.0217&longitude=-79.7839&radius=50&page=1', headers=headers, cookies=cookies)

# %%
response
# Out:
# <Response [200]>

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 440,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=36.0217&location=Greensboro%2C+NC&longitude=-79.7839&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1647183874,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA4NF126246',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA4NF126246',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 239153364,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/03/21/22/38/2022_tesla_model_3-pic-151323069092926303-1024x768.jpeg',
# ...

# %%
type(results_json)
# Out:
# dict

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %%
result_items = results_json['search_results']

# %%
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1647183874,
#  'recent_price_drop': False,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EA4NF126246',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EA4NF126246',
#  'clickoff_url': '',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 239153364,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/03/21/22/38/2022_tesla_model_3-pic-151323069092926303-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--mss_jH0d--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/03/21/22/38/2022_tesla_model_3-pic-151323069092926303-1024x768.jpeg',
#  'lat': 36.0168,
#  'lon': -79.844,
#  'year': 2022,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$53,500',
#  'price_unformatted': 53500,
#  'mileage': '1,518 Miles',
#  'mileage_unformatted': 1518,
#  'city': 'Greensboro',
#  'state': 'NC',
# ...

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
results_json['search_results'][0]['mileage']
# Out:
# '1,518 Miles'

# %%
results_json['search_results'][0]['year']
# Out:
# 2022

# %%
results_json['search_results'][0]['dealer_name']
# Out:
# 'Impex Auto Sales'

# %%
results_json['search_results'][0]['price']
# Out:
# '$53,500'

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_items:
    model.append(result['model'])
    
    mileage.append(result['mileage'])
    
    year.append(result['year'])
    
    dealer_name.append(result['dealer_name'])
    
    price.append(result['price'])

# %%
model
# Out:
# ['Model 3',
#  'Model S',
#  'Model 3',
#  'Model 3',
#  'Model Y',
#  'Model 3',
#  'Model 3',
#  'Model Y',
#  'Model S',
#  'Model S',
#  'Model Y',
#  'Model 3',
#  'Model Y',
#  'Model 3',
#  'Model Y',
#  'Model 3',
#  'Model Y',
#  'Model 3',
#  'Model Y',
#  'Model 3']

# %%
tesla_df = pd.DataFrame({'Model':model,'Mileage':mileage,'Year':year,'Dealer Name':dealer_name,'Price':price})

# %%
tesla_df
# Out:
#       Model       Mileage  Year                          Dealer Name     Price
# 0   Model 3   1,518 Miles  2022                     Impex Auto Sales   $53,500
# 1   Model S  72,572 Miles  2014                      Sanford Imports   $37,999
# 2   Model 3  40,395 Miles  2020                     Impex Auto Sales   $47,900
# 3   Model 3  53,692 Miles  2018                      Sanford Imports   $46,993
# 4   Model Y  10,184 Miles  2020                     Impex Auto Sales   $67,900
# 5   Model 3  11,983 Miles  2021  Jerry Hunt Supercenter Of Salisbury   $55,488
# 6   Model 3  10,662 Miles  2021        EchoPark Automotive Charlotte   $53,589
# 7   Model Y   7,392 Miles  2021                     Impex Auto Sales   $63,900
# 8   Model S                2022                      Smart Chevrolet  $149,998
# 9   Model S  25,651 Miles  2018                     Impex Auto Sales   $77,300
# 10  Model Y  13,060 Miles  2020                     Impex Auto Sales   $66,500
# ...
