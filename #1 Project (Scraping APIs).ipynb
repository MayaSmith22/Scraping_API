# %%
import requests
import pandas as pd

# %%
cookies = {
    '__cflb': '02DiuEnpWqjzEfhLpxZQz37qrxw1gPiwPEhkBsNC1t3ak',
    '_gcl_au': '1.1.2143564524.1648319238',
    '_ga': 'GA1.2.2001351262.1648319238',
    '_gid': 'GA1.2.1868932179.1648319238',
    '.AspNetCore.Antiforgery.OuseQABUvAk': 'CfDJ8M4mE6mWep5EiNRxPXD6kTXxmJ9dJzsSxeb7ufN7i-1Hl4S5AKEZ-7YfJP_UwF5YxyRYVTx6NemxyYB_XC6_nh6IE3PXUP4Hc-gx--8a8bHj6IR4m3OSWNctWfvB-aV4A7CzOnVypDA716HXEgbri9E',
    '_gat_gtag_UA_2325867_1': '1',
}

headers = {
    'authority': 'www.ebooks.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="99", "Google Chrome";v="99"',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.83 Safari/537.36',
    'sec-ch-ua-platform': '"macOS"',
    'content-type': 'application/json',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.ebooks.com/en-us/subjects/computers/?ResultOrder=Popularity&pageNumber=2',
    'accept-language': 'en-US,en;q=0.9',
    # Requests sorts cookies= alphabetically
    # 'cookie': '__cflb=02DiuEnpWqjzEfhLpxZQz37qrxw1gPiwPEhkBsNC1t3ak; _gcl_au=1.1.2143564524.1648319238; _ga=GA1.2.2001351262.1648319238; _gid=GA1.2.1868932179.1648319238; .AspNetCore.Antiforgery.OuseQABUvAk=CfDJ8M4mE6mWep5EiNRxPXD6kTXxmJ9dJzsSxeb7ufN7i-1Hl4S5AKEZ-7YfJP_UwF5YxyRYVTx6NemxyYB_XC6_nh6IE3PXUP4Hc-gx--8a8bHj6IR4m3OSWNctWfvB-aV4A7CzOnVypDA716HXEgbri9E; _gat_gtag_UA_2325867_1=1',
}

params = {
    'ResultOrder': 'Popularity',
    'pageNumber': '2',
    'CountryCode': 'US',
    'subjectId': '13',
}

response = requests.get('https://www.ebooks.com/api/search/subject/', headers=headers, params=params, cookies=cookies)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'search_term': None,
#  'start_record': 11,
#  'total_results': 52512,
#  'books': [{'id': 210467051,
#    'book_url': '/en-us/book/210467051/c-10-pocket-reference/joseph-albahari/',
#    'image_url': 'https://image.ebooks.com/previews/210/210467/210467051/210467051-sml-1.jpg',
#    'image_alt_tag': 'C# 10 Pocket Reference',
#    'title': 'C# 10 Pocket Reference',
#    'edition': '',
#    'subtitle': '',
#    'authors': [{'author_name': 'Joseph Albahari',
#      'author_url': '/en-us/author/joseph-albahari/182770/'},
#     {'author_name': 'Ben Albahari',
#      'author_url': '/en-us/author/ben-albahari/182724/'}],
#    'num_authors': 2,
#    'series': ' Series',
#    'series_number': '',
#    'has_series': False,
#    'series_url': '',
#    'publisher': "O'Reilly Media",
#    'publication_year': '2022',
#    'price': 'US$21.99',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
response.json().keys()
# Out:
# dict_keys(['search_term', 'start_record', 'total_results', 'books', 'pages', 'previous_page', 'next_page'])

# %%
# title
# subtitle
# author 
# publisher 
# publication date
# price

# %%
response.json()['books']
# Out:
# [{'id': 210467051,
#   'book_url': '/en-us/book/210467051/c-10-pocket-reference/joseph-albahari/',
#   'image_url': 'https://image.ebooks.com/previews/210/210467/210467051/210467051-sml-1.jpg',
#   'image_alt_tag': 'C# 10 Pocket Reference',
#   'title': 'C# 10 Pocket Reference',
#   'edition': '',
#   'subtitle': '',
#   'authors': [{'author_name': 'Joseph Albahari',
#     'author_url': '/en-us/author/joseph-albahari/182770/'},
#    {'author_name': 'Ben Albahari',
#     'author_url': '/en-us/author/ben-albahari/182724/'}],
#   'num_authors': 2,
#   'series': ' Series',
#   'series_number': '',
#   'has_series': False,
#   'series_url': '',
#   'publisher': "O'Reilly Media",
#   'publication_year': '2022',
#   'price': 'US$21.99',
# ...

# %%
len(response.json()['books'])
# Out:
# 10

# %%
results_json = (response.json()['books'])

# %%
results_json[0]
# Out:
# {'id': 210467051,
#  'book_url': '/en-us/book/210467051/c-10-pocket-reference/joseph-albahari/',
#  'image_url': 'https://image.ebooks.com/previews/210/210467/210467051/210467051-sml-1.jpg',
#  'image_alt_tag': 'C# 10 Pocket Reference',
#  'title': 'C# 10 Pocket Reference',
#  'edition': '',
#  'subtitle': '',
#  'authors': [{'author_name': 'Joseph Albahari',
#    'author_url': '/en-us/author/joseph-albahari/182770/'},
#   {'author_name': 'Ben Albahari',
#    'author_url': '/en-us/author/ben-albahari/182724/'}],
#  'num_authors': 2,
#  'series': ' Series',
#  'series_number': '',
#  'has_series': False,
#  'series_url': '',
#  'publisher': "O'Reilly Media",
#  'publication_year': '2022',
#  'price': 'US$21.99',
# ...

# %%
# title 
results_json[0]['title']
# Out:
# 'C# 10 Pocket Reference'

# %%
# subtitle
results_json[0]['subtitle']
# Out:
# ''

# %%
# author
results_json[0]['authors'][0]['author_name']
# Out:
# 'Joseph Albahari'

# %%
# publisher
results_json[0]['publisher']
# Out:
# "O'Reilly Media"

# %%
# publication year
results_json[0]['publication_year']
# Out:
# '2022'

# %%
# price
results_json[0]['price']
# Out:
# 'US$21.99'

# %%
title = []
subtitle = []
author = []
publisher = []
publication_year = []
price = []

for result in results_json:
    title.append(result['title'])
    
    subtitle.append(result['subtitle'])
    
    author.append(result['authors'][0]['author_name'])
    
    publisher.append(result['publisher'])
    
    publication_year.append(result['publication_year'])
    
    price.append(result['price'])

# %%
title
# Out:
# ['C# 10 Pocket Reference',
#  'Excel Basics to Blackbelt',
#  'Get Into UX',
#  'Fundamentals of Software Architecture',
#  'Data Science from Scratch',
#  'Architecture Patterns with Python',
#  'Database Internals',
#  'Ten Arguments for Deleting Your Social Media Accounts Right Now',
#  'Learning Go',
#  'Monolith to Microservices']

# %%
subtitle
# Out:
# ['',
#  'An Accelerated Guide to Decision Support Designs',
#  'A foolproof guide to getting your first user experience job',
#  'An Engineering Approach',
#  'First Principles with Python',
#  'Enabling Test-Driven Development, Domain-Driven Design, and Event-Driven Microservices',
#  'A Deep Dive into How Distributed Data Systems Work',
#  '',
#  '',
#  'Evolutionary Patterns to Transform Your Monolith']

# %%
author
# Out:
# ['Joseph Albahari',
#  'Elliot Bendoly',
#  'Vy Alechnavicius',
#  'Mark Richards',
#  'Joel Grus',
#  'Harry Percival',
#  'Alex Petrov',
#  'Jaron Lanier',
#  'Jon Bodner',
#  'Sam Newman']

# %%
price
# Out:
# ['US$21.99',
#  'US$35.99',
#  'US$4.99',
#  'US$59.99',
#  'US$50.99',
#  'US$50.99',
#  'US$50.99',
#  'US$9.99',
#  'US$50.99',
#  'US$42.99']

# %%
books_df = pd.DataFrame({'Title':title,'Subtitle':subtitle,'Author':author,'Publisher':publisher,'Publication Year':publication_year,'Price':price})

# %%
books_df
# Out:
#                                                Title  \
# 0                             C# 10 Pocket Reference
# 1                          Excel Basics to Blackbelt
# 2                                        Get Into UX
# 3              Fundamentals of Software Architecture
# 4                          Data Science from Scratch
# 5                  Architecture Patterns with Python
# 6                                 Database Internals
# 7  Ten Arguments for Deleting Your Social Media A...
# 8                                        Learning Go
# 9                          Monolith to Microservices
#
#                                             Subtitle            Author  \
# 0                                                      Joseph Albahari
# 1   An Accelerated Guide to Decision Support Designs    Elliot Bendoly
# 2  A foolproof guide to getting your first user e...  Vy Alechnavicius
# 3                            An Engineering Approach     Mark Richards
# ...
